# %% [markdown]
# <a href="https://colab.research.google.com/github/signLangProjectNIC/tf-cnn-lstm4/blob/main/TL_keras_vgg16_idea2_1_w.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
import numpy as np
import keras
import os
from PIL import Image
from matplotlib import pyplot as plt
from moviepy.editor import *
import cv2
import moviepy
import sys
import random
import tensorflow.keras.layers as tfKL
import sklearn
from tensorflow.keras import regularizers
from keras.layers import Activation, Dense 
from sklearn.model_selection import train_test_split
import time
from matplotlib import pyplot as plt
import random
import pandas as pd
from tensorflow import keras
from keras.applications.vgg16 import VGG16
from keras import Sequential
from keras.layers import Dense, Concatenate, Input, Lambda,LSTM,Reshape
from keras.models import Model

# %%
from google.colab import drive
drive.mount('/content/gdrive')
mainPath="/content/gdrive/MyDrive/hand sign database"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
nCategories=8

# %%
partition ={}
labels ={}

# %%
partition['train']=list()
partition['validation']=list()
partition['test']=list()

# %%
def mapCatToNumber(file1):
  strings=[]
  for cat in os.listdir(file1):
    strings.append(cat)
  stringsS=sorted(strings)
  answer={}
  for i in range(len(stringsS)):
    answer[stringsS[i]]=i
  return answer
mappingCatToN=mapCatToNumber(mainPath)
print(mappingCatToN)
# Out:
# {'accident': 0, 'call': 1, 'doctor': 2, 'help': 3, 'hot': 4, 'lose': 5, 'pain': 6, 'thief': 7}

# %%
for category in os.listdir(mainPath):
  print(category)
  vidL=[]
  for video in os.listdir(os.path.join(mainPath,category)):
    vidL.append(os.path.join(mainPath,category,video))
  lenVidL=len(vidL)
  trainLen=(int)(3*lenVidL/4)
  testLen=int(lenVidL/10)
  valLen=lenVidL-trainLen-testLen
  print(trainLen," ",valLen," ",testLen)
  random.shuffle(vidL)
  for i in range(lenVidL):
    labels[vidL[i]]=mappingCatToN[category]
    if i<trainLen:
      partition['train'].append(vidL[i])
    elif i<trainLen+valLen:
      partition['validation'].append(vidL[i])
    else:
      partition['test'].append(vidL[i])
# Out:
# hot
# 39   8   5
# call
# 39   8   5
# lose
# 30   6   4
# pain
# 39   8   5
# doctor
# 39   8   5
# accident
# 39   8   5
# thief
# 37   8   5
# help
# 39   8   5

# %%
print(np.shape(partition['train']))
print(np.shape(partition['validation']))
print(np.shape(partition['test']))
# Out:
# (301,)
# (62,)
# (39,)

# %%
import numpy as np
import keras

class DataGenerator(keras.utils.Sequence):
  'Generates data for Keras'
  def __init__(self, list_IDs, labels, batch_size=32, dim=(20,224,224,3), n_classes=8, shuffle=True):
    'Initialization'
    self.dim = dim
    self.batch_size = batch_size
    self.labels = labels
    self.list_IDs = list_IDs
    self.n_classes = n_classes
    self.shuffle = shuffle
    self.on_epoch_end()

  def __len__(self):
    'Denotes the number of batches per epoch'
    return int(np.floor(len(self.list_IDs) / self.batch_size))

  def __getitem__(self, index):
    'Generate one batch of data'
    # Generate indexes of the batch
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

    # Find list of IDs
    list_IDs_temp = [self.list_IDs[k] for k in indexes]

    # Generate data
    X, y = self.__data_generation(list_IDs_temp)

    return X, y

  def on_epoch_end(self):
    'Updates indexes after each epoch'
    self.indexes = np.arange(len(self.list_IDs))
    if self.shuffle == True:
        np.random.shuffle(self.indexes)

  def __data_generation(self, list_IDs_temp):
    'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
    # Initialization
    X = np.empty((self.batch_size, *self.dim))
    y = np.empty((self.batch_size), dtype=int)

    # Generate data
    for i, ID in enumerate(list_IDs_temp):
      # Store sample
      # X[i,] = np.load('data/' + ID + '.npy')
      ######
      # print(ID)
      try:
        vidObj = moviepy.editor.VideoFileClip(ID)
      except IOError as e:
        errno, strerror = e.args
        print(errno)
        print(strerror)
      video_duration = int(vidObj.duration)   
      nFrames=self.dim[0]
      array=np.empty(shape=(nFrames,224,224,3))
      frameSize=(self.dim[1],self.dim[2])
      for k in range(nFrames):
        frame=vidObj.get_frame((k+1)*video_duration/(nFrames*1.0))
        frameR=Image.fromarray(frame).convert("RGB")
        frame2=frameR.resize(frameSize)
        arrayi=np.array(frame2)/255
        del frame,frameR,frame2
        # arrayi=arrayi-np.mean(arrayi)
        # if k is 0:
        #   print(np.shape(arrayi))
        array[k]=arrayi
        del arrayi
      # print(np.shape(array))
      X[i,]=array
      del array
      #######
      # Store class
      y[i] = self.labels[ID]
    print("Shape of X output by data generator: ",np.shape(X))
    return np.array(X), keras.utils.to_categorical(y, num_classes=self.n_classes)

# %%
def createModel4(Tframes=20,batch_size=10,epochs=500,verbose=2,metrics=['accuracy'],loss='categorical_crossentropy',optimizer='adam',nLstmUnits=147):
  input=Input(shape=(Tframes,224,224,3))
  branchOutputs=[]
  bottleNeck=Sequential()
  bottleNeck.add(VGG16(include_top=False))
  branhOutputs=[]
  for i in range(Tframes):
    out=Lambda(lambda x:x[:,i,:,:,:])(input)
    out=bottleNeck(out)
    branhOutputs.append(out)
  out=Concatenate()(branhOutputs)
  out=tfKL.TimeDistributed(LSTM(units=nLstmUnits,activation='tanh',input_shape=(None,7,7,512)))(out)
  out=tfKL.Flatten()(out)
  out=Dense(units=8,activation='softmax')(out)
  model=Model(inputs=input,outputs=out)
  model.compile(optimizer=optimizer,metrics=metrics,loss=loss)
  return model

# %%
# with tpu_strategy.scope():
with tf.device('/device:GPU:0'): 
  Tframes=12
  batch_size=10
  params = {'dim': (Tframes,224,224,3),
            'batch_size': batch_size,
            'n_classes': 8,
            'shuffle': True}

  # Generators
  training_generator = DataGenerator(partition['train'], labels, **params)
  validation_generator = DataGenerator(partition['validation'], labels, **params)


  model=createModel4(Tframes=Tframes)
  begin=time.time()
  history=model.fit_generator(epochs=15,verbose=2,generator=training_generator,
                    validation_data=validation_generator)
  end=time.time()

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

  print("Time taken: ",end-begin)
# Out:
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Epoch 1/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 237s - loss: 2.2224 - accuracy: 0.1167 - val_loss: 2.1197 - val_accuracy: 0.1333
# Epoch 2/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 170s - loss: 2.1125 - accuracy: 0.1167 - val_loss: 2.0928 - val_accuracy: 0.1333
# Epoch 3/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 181s - loss: 2.1217 - accuracy: 0.1400 - val_loss: 2.1170 - val_accuracy: 0.1333
# Epoch 4/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 196s - loss: 2.1170 - accuracy: 0.1133 - val_loss: 2.0979 - val_accuracy: 0.1333
# Epoch 5/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 209s - loss: 2.1196 - accuracy: 0.0900 - val_loss: 2.0878 - val_accuracy: 0.1333
# Epoch 6/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 228s - loss: 2.1193 - accuracy: 0.0900 - val_loss: 2.1063 - val_accuracy: 0.1333
# Epoch 7/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 240s - loss: 2.1407 - accuracy: 0.0867 - val_loss: 2.0858 - val_accuracy: 0.1333
# Epoch 8/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 253s - loss: 2.1194 - accuracy: 0.1133 - val_loss: 2.0996 - val_accuracy: 0.1333
# Epoch 9/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 266s - loss: 2.1266 - accuracy: 0.0933 - val_loss: 2.1092 - val_accuracy: 0.1167
# Epoch 10/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 274s - loss: 2.1112 - accuracy: 0.1333 - val_loss: 2.0915 - val_accuracy: 0.1333
# Epoch 11/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 285s - loss: 2.1264 - accuracy: 0.0733 - val_loss: 2.0810 - val_accuracy: 0.1333
# Epoch 12/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 301s - loss: 2.1121 - accuracy: 0.1100 - val_loss: 2.0996 - val_accuracy: 0.1333
# Epoch 13/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 319s - loss: 2.1047 - accuracy: 0.1400 - val_loss: 2.0911 - val_accuracy: 0.1333
# Epoch 14/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 337s - loss: 2.1116 - accuracy: 0.1067 - val_loss: 2.0912 - val_accuracy: 0.1167
# Epoch 15/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 354s - loss: 2.1079 - accuracy: 0.1033 - val_loss: 2.0906 - val_accuracy: 0.1000
# Time taken:  3851.981402873993

# %%
#15 epochs is the limit

# %%
# looks like underfitting

# %%
# with tpu_strategy.scope():
with tf.device('/device:GPU:0'): 
  Tframes=12
  batch_size=10
  nLstmUnits=1000
  params = {'dim': (Tframes,224,224,3),
            'batch_size': batch_size,
            'n_classes': 8,
            'shuffle': True}

  # Generators
  training_generator = DataGenerator(partition['train'], labels, **params)
  validation_generator = DataGenerator(partition['validation'], labels, **params)


  model=createModel4(Tframes=Tframes,nLstmUnits=nLstmUnits)
  begin=time.time()
  history=model.fit_generator(epochs=15,verbose=2,generator=training_generator,
                    validation_data=validation_generator)
  end=time.time()

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

  print("Time taken: ",end-begin)
# Out:
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Epoch 1/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 209s - loss: 3.2492 - accuracy: 0.1167 - val_loss: 2.3522 - val_accuracy: 0.1333
# Epoch 2/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 174s - loss: 2.3018 - accuracy: 0.1267 - val_loss: 2.2734 - val_accuracy: 0.1333
# Epoch 3/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 188s - loss: 2.2657 - accuracy: 0.1167 - val_loss: 2.2188 - val_accuracy: 0.1333
# Epoch 4/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 204s - loss: 2.3373 - accuracy: 0.1333 - val_loss: 2.1717 - val_accuracy: 0.1333
# Epoch 5/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 218s - loss: 2.3087 - accuracy: 0.1333 - val_loss: 2.1502 - val_accuracy: 0.1167
# Epoch 6/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 238s - loss: 2.3572 - accuracy: 0.0900 - val_loss: 2.3249 - val_accuracy: 0.1333
# Epoch 7/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 256s - loss: 2.2864 - accuracy: 0.0900 - val_loss: 2.2784 - val_accuracy: 0.1333
# Epoch 8/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 268s - loss: 2.3508 - accuracy: 0.1500 - val_loss: 2.5401 - val_accuracy: 0.1167
# Epoch 9/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 280s - loss: 2.3726 - accuracy: 0.1300 - val_loss: 2.2813 - val_accuracy: 0.1333
# Epoch 10/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 289s - loss: 2.4936 - accuracy: 0.0900 - val_loss: 2.3103 - val_accuracy: 0.1333
# Epoch 11/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 295s - loss: 2.3924 - accuracy: 0.1367 - val_loss: 2.3240 - val_accuracy: 0.1167
# Epoch 12/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 312s - loss: 2.3377 - accuracy: 0.1133 - val_loss: 2.2479 - val_accuracy: 0.1333
# Epoch 13/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 330s - loss: 2.2340 - accuracy: 0.1133 - val_loss: 2.1186 - val_accuracy: 0.1333
# Epoch 14/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 347s - loss: 2.3491 - accuracy: 0.1267 - val_loss: 2.6874 - val_accuracy: 0.1333
# Epoch 15/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# 30/30 - 358s - loss: 2.3741 - accuracy: 0.1167 - val_loss: 2.3468 - val_accuracy: 0.1333
# Time taken:  3969.675714969635

# %%
#underfitting

# %%
# with tpu_strategy.scope():
with tf.device('/device:GPU:0'): 
  Tframes=12
  batch_size=10
  nLstmUnits=2000
  params = {'dim': (Tframes,224,224,3),
            'batch_size': batch_size,
            'n_classes': 8,
            'shuffle': True}

  # Generators
  training_generator = DataGenerator(partition['train'], labels, **params)
  validation_generator = DataGenerator(partition['validation'], labels, **params)


  model=createModel4(Tframes=Tframes,nLstmUnits=nLstmUnits)
  begin=time.time()
  history=model.fit_generator(epochs=15,verbose=2,generator=training_generator,
                    validation_data=validation_generator)
  end=time.time()

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

  print("Time taken: ",end-begin)
# Out:
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Epoch 1/15
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
# Shape of X output by data generator:  (10, 12, 224, 224, 3)
